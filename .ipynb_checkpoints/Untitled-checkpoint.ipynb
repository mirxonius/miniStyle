# %%
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data_dir = "img_align_celeba/"
files = os.listdir(data_dir)
img = Image.open(data_dir+files[0])
print(len(os.listdir(data_dir)))
file_name = files[0]
# Out:
# 202599

# %%
img = img.resize((100,100),Image.BICUBIC)
plt.imshow(img)

img.save(data_dir+file_name)
# Out:
# /tmp/ipykernel_9227/362705009.py:1: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   img = img.resize((100,100),Image.BICUBIC)

# %%
img = Image.open(data_dir+files[0])
plt.imshow(img)
